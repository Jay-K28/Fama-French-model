# %% [markdown]
# # **Fama–French 5-Factor Model**
# ### **Factors:** `MKT` | `SMB` | `HML` | `RMW` | `CMA`
#
# ---
#
# ### **Overview**
# - The **Fama–French 5-factor model** explains stock returns using **five systematic risk factors**
# - It extends:
#   - **CAPM**
#   - **Fama–French 3-factor model**
# - Adds:
#   - **Profitability**
#   - **Investment behavior**
#
# ---
#
# ### **Model Equation**
# - **`Ri - Rf = α + βm(MKT) + βs(SMB) + βh(HML) + βr(RMW) + βc(CMA) + ε`**
#
# ---
#
# ### **Terms Explanation**
# - **`Ri`** → Return of asset
# - **`Rf`** → Risk-free rate
# - **`MKT`** → Market return minus risk-free rate
# - **`α` (Alpha)** → Excess return
# - **`ε`** → Error term
#
# ---
#
# ### **Factor Definitions**
#
# #### **1. `MKT` (Market Risk Premium)**
# - **`MKT = Rm - Rf`**
# - Captures overall market movement
#
# ---
#
# #### **2. `SMB` (Small Minus Big)**
# - Small-cap returns − Large-cap returns
# - Proxy: Market capitalization
#
# ---
#
# #### **3. `HML` (High Minus Low)**
# - Value stocks − Growth stocks
# - Proxy: Book-to-market ratio
#
# ---
#
# #### **4. `RMW` (Robust Minus Weak)**
# - High profitability − Low profitability
# - Proxy: ROE, ROA
#
# ---
#
# #### **5. `CMA` (Conservative Minus Aggressive)**
# - Low investment − High investment
# - Proxy: Asset growth
#
# ---
#
# ### **Intuition**
# - Returns are driven by **systematic factor exposure**
# - Each stock has **factor sensitivities (`β`)**
# - These determine expected return
#
# ---
#
# ### **Why This Model Matters**
# - Explains cross-sectional return differences
# - Used in:
#   - Portfolio construction
#   - Quant investing
#   - Asset pricing
#
# ---
#
# ### **Limitations**
# - Linear assumptions
# - Static factors
# - Missing:
#   - `Momentum`
#   - Nonlinear effects
#
# ---
#
# ### **Project Connection**
# - Construct all 5 factors from raw data
# - Use them to:
#   - Explain returns
#   - Generate alpha
# - Extend with ML
#
# ---
#
# ### **Expected Outputs**
# - Factor series: `MKT`, `SMB`, `HML`, `RMW`, `CMA`
# - Factor loadings
# - Alpha
# - Backtest results

# %% [markdown]
# ### Phase 1: Data ingestion and Cleaning (Nifty 500: From 01-01-2011 till date)

# %%
# ==========================================
# Phase 1: Data Collection (NIFTY 100)
# ==========================================

from nselib import capital_market
import pandas as pd
from datetime import date, datetime
import time
import requests
import feedparser
from urllib.parse import quote_plus
import shutil
from pathlib import Path
from transformers import pipeline

# %%
# import sys
# !{sys.executable} -m pip install nselib
# !{sys.executable} -m pip install feedparser

# %%
# =====================================
# STEP 0: Project Setup
# =====================================
PROJECT_ROOT = Path().resolve().parent
DATA_DIR = PROJECT_ROOT / "data"

RAW_DIR = DATA_DIR / "raw"

# Clean full data directory
if DATA_DIR.exists():
    shutil.rmtree(DATA_DIR)

RAW_DIR.mkdir(parents=True, exist_ok=True)

print("Clean data directories ready.")
# Out:
# Clean data directories ready.

# %%
# ====================================
# STEP 1: Fetch NIFTY 100 tickers
# ====================================

url = "https://archives.nseindia.com/content/indices/ind_nifty500list.csv"
df_list = pd.read_csv(url)

tickers = df_list["Symbol"].tolist()

print(f"Total tickers fetched: {len(tickers)}")
# Out:
# Total tickers fetched: 500

# %%
df_list.head()
# Out:
#                Company Name                Industry     Symbol Series  \
# 0          360 ONE WAM Ltd.      Financial Services     360ONE     EQ
# 1             3M India Ltd.             Diversified    3MINDIA     EQ
# 2            ABB India Ltd.           Capital Goods        ABB     EQ
# 3                  ACC Ltd.  Construction Materials        ACC     EQ
# 4  ACME Solar Holdings Ltd.                   Power  ACMESOLAR     EQ
#
#       ISIN Code
# 0  INE466L01038
# 1  INE470A01017
# 2  INE117A01022
# 3  INE012A01025
# 4  INE622W01025

# %%
df_list.shape
# Out:
# (500, 5)

# %%
# ==================================
# STEP 2: Fetch Price + News
# ==================================

def fetch_all_data(symbols, start, end):

    failed = []

    for symbol in symbols:

        try:
            print(f"\n Fetching {symbol} ...")

            df = capital_market.price_volume_and_deliverable_position_data(
                symbol=symbol,
                from_date=start.strftime("%d-%m-%Y"),
                to_date=end.strftime("%d-%m-%Y"),
            )

            if df.empty:
                print(f" No price data for {symbol}")
                failed.append(symbol)
                continue

            df.columns = df.columns.str.lower().str.strip()

            # Keep only EQ series
            if "series" in df.columns:
                df = df[df["series"].str.upper() == "EQ"].copy()

                if df.empty:
                    print(f" {symbol} has no EQ data")
                    failed.append(symbol)
                    continue

            # Save price
            df.to_csv(RAW_DIR / f"{symbol}.csv", index=False)
            print(f" Price saved")

        except Exception as e:
            print(f"Failed: {symbol} | {e}")
            failed.append(symbol)

        time.sleep(1)

    print("\n Data Fetch Completed.")
    print(f" Success: {len(symbols) - len(failed)} | Failed: {len(failed)}")

    if failed:
        pd.DataFrame(failed, columns=["Symbol"]).to_csv(
            DATA_DIR / "failed_tickers.csv", index=False
        )
        print("Failed tickers saved.")

# %%
# ==============================
# Step 3: Execute
# ==============================

START_DATE = date(2011, 1, 1)
END_DATE = date.today()

fetch_all_data(tickers, START_DATE, END_DATE)

print("Total RAW files:", len(list(RAW_DIR.glob("*.csv"))))
# Out:
#  Fetching 360ONE ...
#  Price saved
#
#  Fetching 3MINDIA ...
#  Price saved
#
#  Fetching ABB ...
#  Price saved
#
#  Fetching ACC ...
#  Price saved
#
#  Fetching ACMESOLAR ...
#  Price saved
#
#  Fetching AIAENG ...
#  Price saved
#
#  Fetching APLAPOLLO ...
#  Price saved
#
#  Fetching AUBANK ...
#  Price saved
#
#  Fetching AWL ...
#  Price saved
#
#  Fetching AADHARHFC ...
#  Price saved
#
#  Fetching AARTIIND ...
#  Price saved
#
#  Fetching AAVAS ...
#  Price saved
#
#  Fetching ABBOTINDIA ...
#  Price saved
#
#  Fetching ACE ...
#  Price saved
#
#  Fetching ACUTAAS ...
#  Price saved
#
#  Fetching ADANIENSOL ...
#  Price saved
#
#  Fetching ADANIENT ...
#  Price saved
#
#  Fetching ADANIGREEN ...
#  Price saved
#
#  Fetching ADANIPORTS ...
#  Price saved
#
#  Fetching ADANIPOWER ...
#  Price saved
#
#  Fetching ATGL ...
#  Price saved
#
#  Fetching ABCAPITAL ...
#  Price saved
#
#  Fetching ABFRL ...
#  Price saved
#
#  Fetching ABLBL ...
#  Price saved
#
#  Fetching ABREL ...
#  Price saved
#
#  Fetching ABSLAMC ...
#  Price saved
#
#  Fetching CPPLUS ...
#  Price saved
#
#  Fetching AEGISLOG ...
#  Price saved
#
#  Fetching AEGISVOPAK ...
#  Price saved
#
#  Fetching AFCONS ...
#  Price saved
#
#  Fetching AFFLE ...
#  Price saved
#
#  Fetching AJANTPHARM ...
#  Price saved
#
#  Fetching ALKEM ...
#  Price saved
#
#  Fetching ABDL ...
#  Price saved
#
#  Fetching ARE&M ...
#  Price saved
#
#  Fetching AMBER ...
#  Price saved
#
#  Fetching AMBUJACEM ...
#  Price saved
#
#  Fetching ANANDRATHI ...
#  Price saved
#
#  Fetching ANANTRAJ ...
#  Price saved
#
#  Fetching ANGELONE ...
#  Price saved
#
#  Fetching ANTHEM ...
#  Price saved
#
#  Fetching ANURAS ...
#  Price saved
#
#  Fetching APARINDS ...
#  Price saved
#
#  Fetching APOLLOHOSP ...
#  Price saved
#
#  Fetching APOLLOTYRE ...
#  Price saved
#
#  Fetching APTUS ...
#  Price saved
#
#  Fetching ASAHIINDIA ...
#  Price saved
#
#  Fetching ASHOKLEY ...
#  Price saved
#
#  Fetching ASIANPAINT ...
#  Price saved
#
#  Fetching ASTERDM ...
#  Price saved
#
#  Fetching ASTRAL ...
#  Price saved
#
#  Fetching ATHERENERG ...
#  Price saved
#
#  Fetching ATUL ...
#  Price saved
#
#  Fetching AUROPHARMA ...
#  Price saved
#
#  Fetching AIIL ...
#  Price saved
#
#  Fetching DMART ...
#  Price saved
#
#  Fetching AXISBANK ...
#  Price saved
#
#  Fetching BEML ...
#  Price saved
#
#  Fetching BLS ...
#  Price saved
#
#  Fetching BSE ...
#  Price saved
#
#  Fetching BAJAJ-AUTO ...
#  Price saved
#
#  Fetching BAJFINANCE ...
#  Price saved
#
#  Fetching BAJAJFINSV ...
#  Price saved
#
#  Fetching BAJAJHLDNG ...
#  Price saved
#
#  Fetching BAJAJHFL ...
#  Price saved
#
#  Fetching BALKRISIND ...
#  Price saved
#
#  Fetching BALRAMCHIN ...
#  Price saved
#
#  Fetching BANDHANBNK ...
#  Price saved
#
#  Fetching BANKBARODA ...
#  Price saved
#
#  Fetching BANKINDIA ...
#  Price saved
#
#  Fetching MAHABANK ...
#  Price saved
#
#  Fetching BATAINDIA ...
#  Price saved
#
#  Fetching BAYERCROP ...
#  Price saved
#
#  Fetching BELRISE ...
#  Price saved
#
#  Fetching BERGEPAINT ...
#  Price saved
#
#  Fetching BDL ...
#  Price saved
#
#  Fetching BEL ...
#  Price saved
#
#  Fetching BHARATFORG ...
#  Price saved
#
#  Fetching BHEL ...
#  Price saved
#
#  Fetching BPCL ...
#  Price saved
#
#  Fetching BHARTIARTL ...
#  Price saved
#
#  Fetching BHARTIHEXA ...
#  Price saved
#
#  Fetching BIKAJI ...
#  Price saved
#
#  Fetching GROWW ...
#  Price saved
#
#  Fetching BIOCON ...
#  Price saved
#
#  Fetching BSOFT ...
#  Price saved
#
#  Fetching BLUEDART ...
#  Price saved
#
#  Fetching BLUEJET ...
#  Price saved
#
#  Fetching BLUESTARCO ...
#  Price saved
#
#  Fetching BBTC ...
#  Price saved
#
#  Fetching BOSCHLTD ...
#  Price saved
#
#  Fetching FIRSTCRY ...
#  Price saved
#
#  Fetching BRIGADE ...
#  Price saved
#
#  Fetching BRITANNIA ...
#  Price saved
#
#  Fetching MAPMYINDIA ...
#  Price saved
#
#  Fetching CCL ...
#  Price saved
#
#  Fetching CESC ...
#  Price saved
#
#  Fetching CGPOWER ...
#  Price saved
#
#  Fetching CRISIL ...
#  Price saved
#
#  Fetching CANFINHOME ...
#  Price saved
#
#  Fetching CANBK ...
#  Price saved
#
#  Fetching CANHLIFE ...
#  Price saved
#
#  Fetching CAPLIPOINT ...
#  Price saved
#
#  Fetching CGCL ...
#  Price saved
#
#  Fetching CARBORUNIV ...
#  Price saved
#
#  Fetching CARTRADE ...
#  Price saved
#
#  Fetching CASTROLIND ...
#  Price saved
#
#  Fetching CEATLTD ...
#  Price saved
#
#  Fetching CEMPRO ...
#  Price saved
#
#  Fetching CENTRALBK ...
#  Price saved
#
#  Fetching CDSL ...
#  Price saved
#
#  Fetching CHALET ...
#  Price saved
#
#  Fetching CHAMBLFERT ...
#  Price saved
#
#  Fetching CHENNPETRO ...
#  Price saved
#
#  Fetching CHOICEIN ...
#  Price saved
#
#  Fetching CHOLAHLDNG ...
#  Price saved
#
#  Fetching CHOLAFIN ...
#  Price saved
#
#  Fetching CIPLA ...
#  Price saved
#
#  Fetching CUB ...
#  Price saved
#
#  Fetching CLEAN ...
#  Price saved
#
#  Fetching COALINDIA ...
#  Price saved
#
#  Fetching COCHINSHIP ...
#  Price saved
#
#  Fetching COFORGE ...
#  Price saved
#
#  Fetching COHANCE ...
#  Price saved
#
#  Fetching COLPAL ...
#  Price saved
#
#  Fetching CAMS ...
#  Price saved
#
#  Fetching CONCORDBIO ...
#  Price saved
#
#  Fetching CONCOR ...
#  Price saved
#
#  Fetching COROMANDEL ...
#  Price saved
#
#  Fetching CRAFTSMAN ...
#  Price saved
#
#  Fetching CREDITACC ...
#  Price saved
#
#  Fetching CROMPTON ...
#  Price saved
#
#  Fetching CUMMINSIND ...
#  Price saved
#
#  Fetching CYIENT ...
#  Price saved
#
#  Fetching DCMSHRIRAM ...
#  Price saved
#
#  Fetching DLF ...
#  Price saved
#
#  Fetching DOMS ...
#  Price saved
#
#  Fetching DABUR ...
#  Price saved
#
#  Fetching DALBHARAT ...
#  Price saved
#
#  Fetching DATAPATTNS ...
#  Price saved
#
#  Fetching DEEPAKFERT ...
#  Price saved
#
#  Fetching DEEPAKNTR ...
#  Price saved
#
#  Fetching DELHIVERY ...
#  Price saved
#
#  Fetching DEVYANI ...
#  Price saved
#
#  Fetching DIVISLAB ...
#  Price saved
#
#  Fetching DIXON ...
#  Price saved
#
#  Fetching LALPATHLAB ...
#  Price saved
#
#  Fetching DRREDDY ...
#  Price saved
#
#  Fetching EIDPARRY ...
#  Price saved
#
#  Fetching EIHOTEL ...
#  Price saved
#
#  Fetching EICHERMOT ...
#  Price saved
#
#  Fetching ELECON ...
#  Price saved
#
#  Fetching ELGIEQUIP ...
#  Price saved
#
#  Fetching EMAMILTD ...
# Failed: EMAMILTD |  Resource not available MSG: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
#  Fetching EMCURE ...
# Failed: EMCURE |  Resource not available MSG: HTTPSConnectionPool(host='nsewebsite-staging.nseindia.com', port=443): Max retries exceeded with url: /report-detail/eq_security (Caused by NameResolutionError("HTTPSConnection(host='nsewebsite-staging.nseindia.com', port=443): Failed to resolve 'nsewebsite-staging.nseindia.com' ([Errno 11001] getaddrinfo failed)"))
#
#  Fetching EMMVEE ...
# Failed: EMMVEE |  Resource not available MSG: HTTPSConnectionPool(host='nsewebsite-staging.nseindia.com', port=443): Max retries exceeded with url: /report-detail/eq_security (Caused by NameResolutionError("HTTPSConnection(host='nsewebsite-staging.nseindia.com', port=443): Failed to resolve 'nsewebsite-staging.nseindia.com' ([Errno 11001] getaddrinfo failed)"))
#
#  Fetching ENDURANCE ...
# Failed: ENDURANCE |  Resource not available MSG: HTTPSConnectionPool(host='nsewebsite-staging.nseindia.com', port=443): Max retries exceeded with url: /report-detail/eq_security (Caused by NameResolutionError("HTTPSConnection(host='nsewebsite-staging.nseindia.com', port=443): Failed to resolve 'nsewebsite-staging.nseindia.com' ([Errno 11001] getaddrinfo failed)"))
#
#  Fetching ENGINERSIN ...
# Failed: ENGINERSIN |  Resource not available MSG: HTTPSConnectionPool(host='nsewebsite-staging.nseindia.com', port=443): Max retries exceeded with url: /report-detail/eq_security (Caused by NameResolutionError("HTTPSConnection(host='nsewebsite-staging.nseindia.com', port=443): Failed to resolve 'nsewebsite-staging.nseindia.com' ([Errno 11001] getaddrinfo failed)"))
#
#  Fetching ERIS ...
# Failed: ERIS |  Resource not available MSG: HTTPSConnectionPool(host='nsewebsite-staging.nseindia.com', port=443): Max retries exceeded with url: /report-detail/eq_security (Caused by NameResolutionError("HTTPSConnection(host='nsewebsite-staging.nseindia.com', port=443): Failed to resolve 'nsewebsite-staging.nseindia.com' ([Errno 11001] getaddrinfo failed)"))
#
#  Fetching ESCORTS ...
# Failed: ESCORTS |  Resource not available MSG: HTTPSConnectionPool(host='nsewebsite-staging.nseindia.com', port=443): Max retries exceeded with url: /report-detail/eq_security (Caused by NameResolutionError("HTTPSConnection(host='nsewebsite-staging.nseindia.com', port=443): Failed to resolve 'nsewebsite-staging.nseindia.com' ([Errno 11001] getaddrinfo failed)"))
#
#  Fetching ETERNAL ...
# Failed: ETERNAL |  Resource not available MSG: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#  Fetching EXIDEIND ...
# Failed: EXIDEIND |  Resource not available MSG: HTTPSConnectionPool(host='nsewebsite-staging.nseindia.com', port=443): Max retries exceeded with url: /report-detail/eq_security (Caused by NameResolutionError("HTTPSConnection(host='nsewebsite-staging.nseindia.com', port=443): Failed to resolve 'nsewebsite-staging.nseindia.com' ([Errno 11001] getaddrinfo failed)"))
#
#  Fetching NYKAA ...
# Failed: NYKAA |  Resource not available MSG: HTTPSConnectionPool(host='nsewebsite-staging.nseindia.com', port=443): Max retries exceeded with url: /report-detail/eq_security (Caused by NameResolutionError("HTTPSConnection(host='nsewebsite-staging.nseindia.com', port=443): Failed to resolve 'nsewebsite-staging.nseindia.com' ([Errno 11001] getaddrinfo failed)"))
#
#  Fetching FEDERALBNK ...
# Failed: FEDERALBNK |  Resource not available MSG: HTTPSConnectionPool(host='nsewebsite-staging.nseindia.com', port=443): Max retries exceeded with url: /report-detail/eq_security (Caused by NameResolutionError("HTTPSConnection(host='nsewebsite-staging.nseindia.com', port=443): Failed to resolve 'nsewebsite-staging.nseindia.com' ([Errno 11001] getaddrinfo failed)"))
#
#  Fetching FACT ...
# Failed: FACT |  Resource not available MSG: HTTPSConnectionPool(host='nsewebsite-staging.nseindia.com', port=443): Max retries exceeded with url: /report-detail/eq_security (Caused by NameResolutionError("HTTPSConnection(host='nsewebsite-staging.nseindia.com', port=443): Failed to resolve 'nsewebsite-staging.nseindia.com' ([Errno 11001] getaddrinfo failed)"))
#
#  Fetching FINCABLES ...
# Failed: FINCABLES |  Resource not available MSG: HTTPSConnectionPool(host='nsewebsite-staging.nseindia.com', port=443): Max retries exceeded with url: /report-detail/eq_security (Caused by NameResolutionError("HTTPSConnection(host='nsewebsite-staging.nseindia.com', port=443): Failed to resolve 'nsewebsite-staging.nseindia.com' ([Errno 11001] getaddrinfo failed)"))
#
#  Fetching FSL ...
# Failed: FSL |  Resource not available MSG: HTTPSConnectionPool(host='nsewebsite-staging.nseindia.com', port=443): Max retries exceeded with url: /report-detail/eq_security (Caused by NameResolutionError("HTTPSConnection(host='nsewebsite-staging.nseindia.com', port=443): Failed to resolve 'nsewebsite-staging.nseindia.com' ([Errno 11001] getaddrinfo failed)"))
#
#  Fetching FIVESTAR ...
#  Price saved
#
#  Fetching FORCEMOT ...
#  Price saved
#
#  Fetching FORTIS ...
#  Price saved
#
#  Fetching GAIL ...
#  Price saved
#
#  Fetching GVT&D ...
#  Price saved
#
#  Fetching GMRAIRPORT ...
#  Price saved
#
#  Fetching GABRIEL ...
#  Price saved
#
#  Fetching GALLANTT ...
#  Price saved
#
#  Fetching GRSE ...
#  Price saved
#
#  Fetching GICRE ...
#  Price saved
#
#  Fetching GILLETTE ...
#  Price saved
#
#  Fetching GLAND ...
#  Price saved
#
#  Fetching GLAXO ...
#  Price saved
#
#  Fetching GLENMARK ...
#  Price saved
#
#  Fetching MEDANTA ...
#  Price saved
#
#  Fetching GODIGIT ...
#  Price saved
#
#  Fetching GPIL ...
#  Price saved
#
#  Fetching GODFRYPHLP ...
#  Price saved
#
#  Fetching GODREJCP ...
#  Price saved
#
#  Fetching GODREJIND ...
#  Price saved
#
#  Fetching GODREJPROP ...
#  Price saved
#
#  Fetching GRANULES ...
#  Price saved
#
#  Fetching GRAPHITE ...
#  Price saved
#
#  Fetching GRASIM ...
#  Price saved
#
#  Fetching GRAVITA ...
#  Price saved
#
#  Fetching GESHIP ...
#  Price saved
#
#  Fetching FLUOROCHEM ...
#  Price saved
#
#  Fetching GMDCLTD ...
#  Price saved
#
#  Fetching GSPL ...
#  Price saved
#
#  Fetching HEG ...
#  Price saved
#
#  Fetching HBLENGINE ...
#  Price saved
#
#  Fetching HCLTECH ...
#  Price saved
#
#  Fetching HDBFS ...
#  Price saved
#
#  Fetching HDFCAMC ...
#  Price saved
#
#  Fetching HDFCBANK ...
#  Price saved
#
#  Fetching HDFCLIFE ...
#  Price saved
#
#  Fetching HFCL ...
#  Price saved
#
#  Fetching HAVELLS ...
#  Price saved
#
#  Fetching HEROMOTOCO ...
#  Price saved
#
#  Fetching HEXT ...
#  Price saved
#
#  Fetching HSCL ...
#  Price saved
#
#  Fetching HINDALCO ...
#  Price saved
#
#  Fetching HAL ...
#  Price saved
#
#  Fetching HINDCOPPER ...
#  Price saved
#
#  Fetching HINDPETRO ...
#  Price saved
#
#  Fetching HINDUNILVR ...
#  Price saved
#
#  Fetching HINDZINC ...
#  Price saved
#
#  Fetching POWERINDIA ...
#  Price saved
#
#  Fetching HOMEFIRST ...
#  Price saved
#
#  Fetching HONASA ...
#  Price saved
#
#  Fetching HONAUT ...
#  Price saved
#
#  Fetching HUDCO ...
#  Price saved
#
#  Fetching HYUNDAI ...
#  Price saved
#
#  Fetching ICICIBANK ...
#  Price saved
#
#  Fetching ICICIGI ...
#  Price saved
#
#  Fetching ICICIAMC ...
#  Price saved
#
#  Fetching ICICIPRULI ...
#  Price saved
#
#  Fetching IDBI ...
#  Price saved
#
#  Fetching IDFCFIRSTB ...
#  Price saved
#
#  Fetching IFCI ...
#  Price saved
#
#  Fetching IIFL ...
#  Price saved
#
#  Fetching IRB ...
#  Price saved
#
#  Fetching IRCON ...
#  Price saved
#
#  Fetching ITCHOTELS ...
#  Price saved
#
#  Fetching ITC ...
#  Price saved
#
#  Fetching ITI ...
#  Price saved
#
#  Fetching INDGN ...
#  Price saved
#
#  Fetching INDIACEM ...
#  Price saved
#
#  Fetching INDIAMART ...
#  Price saved
#
#  Fetching INDIANB ...
#  Price saved
#
#  Fetching IEX ...
#  Price saved
#
#  Fetching INDHOTEL ...
#  Price saved
#
#  Fetching IOC ...
#  Price saved
#
#  Fetching IOB ...
#  Price saved
#
#  Fetching IRCTC ...
#  Price saved
#
#  Fetching IRFC ...
#  Price saved
#
#  Fetching IREDA ...
#  Price saved
#
#  Fetching IGL ...
#  Price saved
#
#  Fetching INDUSTOWER ...
#  Price saved
#
#  Fetching INDUSINDBK ...
#  Price saved
#
#  Fetching NAUKRI ...
#  Price saved
#
#  Fetching INFY ...
#  Price saved
#
#  Fetching INOXWIND ...
#  Price saved
#
#  Fetching INTELLECT ...
#  Price saved
#
#  Fetching INDIGO ...
#  Price saved
#
#  Fetching IGIL ...
#  Price saved
#
#  Fetching IKS ...
#  Price saved
#
#  Fetching IPCALAB ...
#  Price saved
#
#  Fetching JBCHEPHARM ...
#  Price saved
#
#  Fetching JKCEMENT ...
#  Price saved
#
#  Fetching JBMA ...
#  Price saved
#
#  Fetching JKTYRE ...
#  Price saved
#
#  Fetching JMFINANCIL ...
#  Price saved
#
#  Fetching JSWCEMENT ...
#  Price saved
#
#  Fetching JSWDULUX ...
#  Price saved
#
#  Fetching JSWENERGY ...
#  Price saved
#
#  Fetching JSWINFRA ...
#  Price saved
#
#  Fetching JSWSTEEL ...
#  Price saved
#
#  Fetching JAINREC ...
#  Price saved
#
#  Fetching JPPOWER ...
#  Price saved
#
#  Fetching J&KBANK ...
#  Price saved
#
#  Fetching JINDALSAW ...
#  Price saved
#
#  Fetching JSL ...
# Failed: JSL |  Resource not available MSG: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
#  Fetching JINDALSTEL ...
# Failed: JINDALSTEL |  Resource not available MSG: HTTPSConnectionPool(host='nsewebsite-staging.nseindia.com', port=443): Max retries exceeded with url: /report-detail/eq_security (Caused by NameResolutionError("HTTPSConnection(host='nsewebsite-staging.nseindia.com', port=443): Failed to resolve 'nsewebsite-staging.nseindia.com' ([Errno 11001] getaddrinfo failed)"))
#
#  Fetching JIOFIN ...
# Failed: JIOFIN |  Resource not available MSG: HTTPSConnectionPool(host='nsewebsite-staging.nseindia.com', port=443): Max retries exceeded with url: /report-detail/eq_security (Caused by NameResolutionError("HTTPSConnection(host='nsewebsite-staging.nseindia.com', port=443): Failed to resolve 'nsewebsite-staging.nseindia.com' ([Errno 11001] getaddrinfo failed)"))
#
#  Fetching JUBLFOOD ...
# Failed: JUBLFOOD |  Resource not available MSG: HTTPSConnectionPool(host='nsewebsite-staging.nseindia.com', port=443): Max retries exceeded with url: /report-detail/eq_security (Caused by NameResolutionError("HTTPSConnection(host='nsewebsite-staging.nseindia.com', port=443): Failed to resolve 'nsewebsite-staging.nseindia.com' ([Errno 11001] getaddrinfo failed)"))
#
#  Fetching JUBLINGREA ...
# Failed: JUBLINGREA |  Resource not available MSG: HTTPSConnectionPool(host='nsewebsite-staging.nseindia.com', port=443): Max retries exceeded with url: /report-detail/eq_security (Caused by NameResolutionError("HTTPSConnection(host='nsewebsite-staging.nseindia.com', port=443): Failed to resolve 'nsewebsite-staging.nseindia.com' ([Errno 11001] getaddrinfo failed)"))
#
#  Fetching JUBLPHARMA ...
# Failed: JUBLPHARMA |  Resource not available MSG: HTTPSConnectionPool(host='nsewebsite-staging.nseindia.com', port=443): Max retries exceeded with url: /report-detail/eq_security (Caused by NameResolutionError("HTTPSConnection(host='nsewebsite-staging.nseindia.com', port=443): Failed to resolve 'nsewebsite-staging.nseindia.com' ([Errno 11001] getaddrinfo failed)"))
#
#  Fetching JWL ...
# Failed: JWL |  Resource not available MSG: HTTPSConnectionPool(host='nsewebsite-staging.nseindia.com', port=443): Max retries exceeded with url: /report-detail/eq_security (Caused by NameResolutionError("HTTPSConnection(host='nsewebsite-staging.nseindia.com', port=443): Failed to resolve 'nsewebsite-staging.nseindia.com' ([Errno 11001] getaddrinfo failed)"))
#  Fetching JYOTICNC ...
#  Price saved
#
#  Fetching KPRMILL ...
#  Price saved
#
#  Fetching KEI ...
#  Price saved
#
#  Fetching KPITTECH ...
#  Price saved
#
#  Fetching KAJARIACER ...
#  Price saved
#
#  Fetching KPIL ...
#  Price saved
#
#  Fetching KALYANKJIL ...
#  Price saved
#
#  Fetching KARURVYSYA ...
#  Price saved
#
#  Fetching KAYNES ...
#  Price saved
#
#  Fetching KEC ...
#  Price saved
#
#  Fetching KFINTECH ...
#  Price saved
#
#  Fetching KIRLOSENG ...
#  Price saved
#
#  Fetching KOTAKBANK ...
#  Price saved
#
#  Fetching KIMS ...
#  Price saved
#
#  Fetching LTF ...
#  Price saved
#
#  Fetching LTTS ...
#  Price saved
#
#  Fetching LGEINDIA ...
#  Price saved
#
#  Fetching LICHSGFIN ...
#  Price saved
#
#  Fetching LTFOODS ...
#  Price saved
#
#  Fetching LTM ...
#  Price saved
#
#  Fetching LT ...
#  Price saved
#
#  Fetching LATENTVIEW ...
#  Price saved
#
#  Fetching LAURUSLABS ...
#  Price saved
#
#  Fetching THELEELA ...
#  Price saved
#
#  Fetching LEMONTREE ...
#  Price saved
#
#  Fetching LENSKART ...
#  Price saved
#
#  Fetching LICI ...
#  Price saved
#
#  Fetching LINDEINDIA ...
#  Price saved
#
#  Fetching LLOYDSME ...
#  Price saved
#
#  Fetching LODHA ...
#  Price saved
#
#  Fetching LUPIN ...
#  Price saved
#
#  Fetching MMTC ...
#  Price saved
#
#  Fetching MRF ...
#  Price saved
#
#  Fetching MGL ...
#  Price saved
#
#  Fetching M&MFIN ...
#  Price saved
#
#  Fetching M&M ...
#  Price saved
#
#  Fetching MANAPPURAM ...
#  Price saved
#
#  Fetching MRPL ...
#  Price saved
#
#  Fetching MANKIND ...
#  Price saved
#
#  Fetching MARICO ...
#  Price saved
#
#  Fetching MARUTI ...
#  Price saved
#
#  Fetching MFSL ...
#  Price saved
#
#  Fetching MAXHEALTH ...
#  Price saved
#
#  Fetching MAZDOCK ...
#  Price saved
#
#  Fetching MEESHO ...
#  Price saved
#
#  Fetching MINDACORP ...
#  Price saved
#
#  Fetching MSUMI ...
#  Price saved
#
#  Fetching MOTILALOFS ...
#  Price saved
#
#  Fetching MPHASIS ...
#  Price saved
#
#  Fetching MCX ...
#  Price saved
#
#  Fetching MUTHOOTFIN ...
#  Price saved
#
#  Fetching NATCOPHARM ...
#  Price saved
#
#  Fetching NBCC ...
#  Price saved
#
#  Fetching NCC ...
#  Price saved
#
#  Fetching NHPC ...
#  Price saved
#
#  Fetching NLCINDIA ...
#  Price saved
#
#  Fetching NMDC ...
#  Price saved
#
#  Fetching NSLNISP ...
#  Price saved
#
#  Fetching NTPCGREEN ...
#  Price saved
#
#  Fetching NTPC ...
#  Price saved
#
#  Fetching NH ...
#  Price saved
#
#  Fetching NATIONALUM ...
#  Price saved
#
#  Fetching NAVA ...
#  Price saved
#
#  Fetching NAVINFLUOR ...
#  Price saved
#
#  Fetching NESTLEIND ...
#  Price saved
#
#  Fetching NETWEB ...
#  Price saved
#
#  Fetching NEULANDLAB ...
#  Price saved
#
#  Fetching NEWGEN ...
#  Price saved
#
#  Fetching NAM-INDIA ...
#  Price saved
#
#  Fetching NIVABUPA ...
#  Price saved
#
#  Fetching NUVAMA ...
#  Price saved
#
#  Fetching NUVOCO ...
#  Price saved
#
#  Fetching OBEROIRLTY ...
#  Price saved
#
#  Fetching ONGC ...
#  Price saved
#
#  Fetching OIL ...
#  Price saved
#
#  Fetching OLAELEC ...
#  Price saved
#
#  Fetching OLECTRA ...
#  Price saved
#
#  Fetching PAYTM ...
#  Price saved
#
#  Fetching ONESOURCE ...
#  Price saved
#
#  Fetching OFSS ...
#  Price saved
#
#  Fetching POLICYBZR ...
#  Price saved
#
#  Fetching PCBL ...
#  Price saved
#
#  Fetching PGEL ...
#  Price saved
#
#  Fetching PIIND ...
#  Price saved
#
#  Fetching PNBHOUSING ...
#  Price saved
#
#  Fetching PTCIL ...
#  Price saved
#
#  Fetching PVRINOX ...
#  Price saved
#
#  Fetching PAGEIND ...
#  Price saved
#
#  Fetching PARADEEP ...
#  Price saved
#
#  Fetching PATANJALI ...
#  Price saved
#
#  Fetching PERSISTENT ...
#  Price saved
#
#  Fetching PETRONET ...
#  Price saved
#
#  Fetching PFIZER ...
#  Price saved
#
#  Fetching PHOENIXLTD ...
#  Price saved
#
#  Fetching PWL ...
#  Price saved
#
#  Fetching PIDILITIND ...
#  Price saved
#
#  Fetching PINELABS ...
#  Price saved
#
#  Fetching PIRAMALFIN ...
#  Price saved
#
#  Fetching PPLPHARMA ...
#  Price saved
#
#  Fetching POLYMED ...
#  Price saved
#
#  Fetching POLYCAB ...
#  Price saved
#
#  Fetching POONAWALLA ...
#  Price saved
#
#  Fetching PFC ...
#  Price saved
#
#  Fetching POWERGRID ...
#  Price saved
#
#  Fetching PREMIERENE ...
#  Price saved
#
#  Fetching PRESTIGE ...
#  Price saved
#
#  Fetching PNB ...
#  Price saved
#
#  Fetching RRKABEL ...
#  Price saved
#
#  Fetching RBLBANK ...
#  Price saved
#
#  Fetching RECLTD ...
#  Price saved
#
#  Fetching RHIM ...
#  Price saved
#
#  Fetching RITES ...
#  Price saved
#
#  Fetching RADICO ...
#  Price saved
#
#  Fetching RVNL ...
#  Price saved
#
#  Fetching RAILTEL ...
#  Price saved
#
#  Fetching RAINBOW ...
#  Price saved
#
#  Fetching RKFORGE ...
#  Price saved
#
#  Fetching REDINGTON ...
#  Price saved
#
#  Fetching RELIANCE ...
#  Price saved
#
#  Fetching RPOWER ...
#  Price saved
#
#  Fetching SBFC ...
#  Price saved
#
#  Fetching SBICARD ...
#  Price saved
#
#  Fetching SBILIFE ...
#  Price saved
#
#  Fetching SJVN ...
#  Price saved
#
#  Fetching SRF ...
#  Price saved
#
#  Fetching SAGILITY ...
#  Price saved
#
#  Fetching SAILIFE ...
#  Price saved
#
#  Fetching SAMMAANCAP ...
#  Price saved
#
#  Fetching MOTHERSON ...
#  Price saved
#
#  Fetching SAPPHIRE ...
#  Price saved
#
#  Fetching SARDAEN ...
#  Price saved
#
#  Fetching SAREGAMA ...
#  Price saved
#
#  Fetching SCHAEFFLER ...
#  Price saved
#
#  Fetching SCHNEIDER ...
#  Price saved
#
#  Fetching SCI ...
#  Price saved
#
#  Fetching SHREECEM ...
#  Price saved
#
#  Fetching SHRIRAMFIN ...
#  Price saved
#
#  Fetching SHYAMMETL ...
#  Price saved
#
#  Fetching ENRIN ...
#  Price saved
#
#  Fetching SIEMENS ...
#  Price saved
#
#  Fetching SIGNATURE ...
#  Price saved
#
#  Fetching SOBHA ...
#  Price saved
#
#  Fetching SOLARINDS ...
#  Price saved
#
#  Fetching SONACOMS ...
#  Price saved
#
#  Fetching SONATSOFTW ...
#  Price saved
#
#  Fetching STARHEALTH ...
#  Price saved
#
#  Fetching SBIN ...
#  Price saved
#
#  Fetching SAIL ...
#  Price saved
#
#  Fetching SUMICHEM ...
#  Price saved
#
#  Fetching SUNPHARMA ...
#  Price saved
#
#  Fetching SUNTV ...
#  Price saved
#
#  Fetching SUNDARMFIN ...
#  Price saved
#
#  Fetching SUPREMEIND ...
#  Price saved
#
#  Fetching SPLPETRO ...
#  Price saved
#
#  Fetching SUZLON ...
#  Price saved
#
#  Fetching SWANCORP ...
#  Price saved
#
#  Fetching SWIGGY ...
#  Price saved
#
#  Fetching SYNGENE ...
#  Price saved
#
#  Fetching SYRMA ...
#  Price saved
#
#  Fetching TBOTEK ...
#  Price saved
#
#  Fetching TVSMOTOR ...
#  Price saved
#
#  Fetching TATACAP ...
#  Price saved
#
#  Fetching TATACHEM ...
#  Price saved
#
#  Fetching TATACOMM ...
#  Price saved
#
#  Fetching TCS ...
#  Price saved
#
#  Fetching TATACONSUM ...
#  Price saved
#
#  Fetching TATAELXSI ...
#  Price saved
#
#  Fetching TATAINVEST ...
#  Price saved
#
#  Fetching TMCV ...
#  Price saved
#
#  Fetching TMPV ...
#  Price saved
#
#  Fetching TATAPOWER ...
#  Price saved
#
#  Fetching TATASTEEL ...
#  Price saved
#
#  Fetching TATATECH ...
#  Price saved
#
#  Fetching TTML ...
#  Price saved
#
#  Fetching TECHM ...
#  Price saved
#
#  Fetching TECHNOE ...
#  Price saved
#
#  Fetching TEGA ...
#  Price saved
#
#  Fetching TEJASNET ...
#  Price saved
#
#  Fetching TENNIND ...
#  Price saved
#
#  Fetching NIACL ...
#  Price saved
#
#  Fetching RAMCOCEM ...
#  Price saved
#
#  Fetching THERMAX ...
#  Price saved
#
#  Fetching TIMKEN ...
#  Price saved
#
#  Fetching TITAGARH ...
#  Price saved
#
#  Fetching TITAN ...
#  Price saved
#
#  Fetching TORNTPHARM ...
#  Price saved
#
#  Fetching TORNTPOWER ...
#  Price saved
#
#  Fetching TARIL ...
#  Price saved
#
#  Fetching TRAVELFOOD ...
#  Price saved
#
#  Fetching TRENT ...
#  Price saved
#
#  Fetching TRIDENT ...
#  Price saved
#
#  Fetching TRITURBINE ...
#  Price saved
#
#  Fetching TIINDIA ...
#  Price saved
#
#  Fetching UCOBANK ...
#  Price saved
#
#  Fetching UNOMINDA ...
#  Price saved
#
#  Fetching UPL ...
#  Price saved
#
#  Fetching UTIAMC ...
#  Price saved
#
#  Fetching ULTRACEMCO ...
#  Price saved
#
#  Fetching UNIONBANK ...
#  Price saved
#
#  Fetching UBL ...
#  Price saved
#
#  Fetching UNITDSPR ...
#  Price saved
#
#  Fetching URBANCO ...
#  Price saved
#
#  Fetching USHAMART ...
#  Price saved
#
#  Fetching VTL ...
#  Price saved
#
#  Fetching VBL ...
#  Price saved
#
#  Fetching VEDL ...
#  Price saved
#
#  Fetching VIJAYA ...
#  Price saved
#
#  Fetching VMM ...
#  Price saved
#
#  Fetching IDEA ...
#  Price saved
#
#  Fetching VOLTAS ...
#  Price saved
#
#  Fetching WAAREEENER ...
#  Price saved
#
#  Fetching WELCORP ...
#  Price saved
#
#  Fetching WELSPUNLIV ...
#  Price saved
#
#  Fetching WHIRLPOOL ...
#  Price saved
#
#  Fetching WIPRO ...
#  Price saved
#
#  Fetching WOCKPHARMA ...
#  Price saved
#
#  Fetching YESBANK ...
#  Price saved
#
#  Fetching ZFCVINDIA ...
#  Price saved
#
#  Fetching ZEEL ...
#  Price saved
#
#  Fetching ZENTEC ...
#  Price saved
#
#  Fetching ZENSARTECH ...
#  Price saved
#
#  Fetching ZYDUSLIFE ...
#  Price saved
#
#  Fetching ZYDUSWELL ...
#  Price saved
#
#  Fetching ECLERX ...
#  Price saved
#
#  Data Fetch Completed.
#  Success: 479 | Failed: 21
# Failed tickers saved.
# Total RAW files: 479

# %%
url = "https://fred.stlouisfed.org/graph/fredgraph.csv?id=INDIR3TIB01STM"

df = pd.read_csv(url)
df['DATE'] = pd.to_datetime(df['observation_date'])

df = df.set_index('DATE')
df.rename(columns={'INDIR3TIB01STM': 'Rf'}, inplace=True)

df['Rf'] = df['Rf'] / 100
df = df.resample('D').ffill()
df['Rf_daily'] = df['Rf'] / 365

# %%
df.head()
# Out:
#            observation_date       Rf  Rf_daily
# DATE
# 2011-11-01       2011-11-01  0.08869  0.000243
# 2011-11-02       2011-11-01  0.08869  0.000243
# 2011-11-03       2011-11-01  0.08869  0.000243
# 2011-11-04       2011-11-01  0.08869  0.000243
# 2011-11-05       2011-11-01  0.08869  0.000243
